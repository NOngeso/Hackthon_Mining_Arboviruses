# %%
# 1. importing necessary libraries
import pandas as pd# fro preparing dataframe
import numpy as np
import matplotlib.pyplot as plt # for visualizing clusters
from matplotlib import style
style.use("ggplot") # choosing the style for visualising clusters
from scipy.cluster.hierarchy import linkage,dendrogram #descriptive analytic 
from sklearn.cluster import KMeans #Descriptive analytic algorithm
from sklearn import preprocessing # for preparing data
from sklearn.preprocessing import Normalizer # For Normalizing data
from numpy import set_printoptions # for limiting number decimals
from sklearn.decomposition import PCA # for reducing attributes
from sklearn.model_selection import train_test_split

# %%
# 2. #extracting data
path='C:/Users/User/Desktop/Data/protein_file.csv'
attributes=['Molecular_Weight','Gravity','Aromaticity','Instability','Isoelectic_Point','Compartment']
data=pd.read_csv(path, names=attributes)
print(data)
# Out:
#      Molecular_Weight   Gravity  Aromaticity  Instability  Isoelectic_Point  \
# 0          93323.4594 -0.213571     0.075000    33.803119          5.995056
# 1          27949.8955 -0.740000     0.077551    48.864980          4.799377
# 2          17453.7134 -0.450327     0.098039    37.247124          6.489685
# 3          35268.1468 -0.009366     0.063444    30.649245          8.177429
# 4          25718.5138 -0.406912     0.142857    36.475576          8.082214
# 5         120634.5465 -0.098273     0.088182    34.071391          6.960754
# 6         250774.6466 -0.300983     0.082700    40.815919          5.869080
# 7          36569.4096 -0.055917     0.082840    19.513609          7.596985
# 8          25318.1366 -0.447727     0.081818    37.295909          8.694397
# 9          48297.1855 -0.343678     0.071264    33.785310          8.733215
# 10         42137.1258 -0.597855     0.107239    44.941019          6.640320
# 11         58065.7220  0.008534     0.025974    36.706122          8.237488
# 12         16341.0380 -0.317089     0.031646    17.428481          6.482849
# 13         33219.9612 -0.600000     0.094077    33.946725          4.859436
# 14        122943.1471 -0.599912     0.063717    52.134345          8.797913
# 15         21898.8698 -0.076119     0.084577    47.526368          6.146667
# 16         11006.3533 -0.677551     0.081633    22.532653          5.381409
# 17         38628.8645 -0.003039     0.049724    31.969890          5.093323
# 18         38753.1242 -0.441369     0.110119    39.405357          9.241882
# 19         35537.1575 -0.203537     0.115756    27.675595          5.232727
# 20         34582.6007 -0.087459     0.099010    42.583531          7.625671
# 21         78735.5332 -0.370597     0.056818    41.267060          7.674866
# 22         17931.1049 -0.440127     0.089172    51.863057          6.475037
# 23         40572.7769 -0.497222     0.066667    54.905000          6.199280
# 24         47250.7644 -0.175346     0.064516    42.966129          6.183533
# 25         28960.0173 -0.586486     0.104247    30.166409          6.519714
# 26         80005.5000 -0.425286     0.107143    41.548729          4.917419
# 27        137415.6898 -0.225518     0.080365    43.039031          5.435608
# 28         64148.8643 -0.220280     0.082168    39.732360          5.789490
# 29        249235.0952 -0.311002     0.077370    48.303676          8.509827
# ..                ...       ...          ...          ...               ...
# 707        23888.5532 -0.281776     0.056075    36.358878          9.897278
# 708        73547.9444 -0.286293     0.101246    37.564953          9.445618
# 709        49397.6805 -0.144912     0.048673    35.488496          6.718811
# 710        12826.2396 -0.175214     0.042735    41.164103          4.348328
# 711        19959.6638 -0.716959     0.093567    48.658480          8.268127
# 712        57216.7057 -0.225532     0.094778    23.649710          6.406677
# 713        37368.7612 -0.404630     0.098765    35.334877          9.910339
# 714        85356.2978 -0.328718     0.067949    32.791795          8.079529
# 715        73778.7780 -0.406333     0.047128    39.134624          5.970642
# 716        43226.0110 -0.788410     0.088949    50.470108          9.819275
# 717        35079.1508  0.145946     0.054054    27.451652          8.617615
# 718        13625.2014 -0.323529     0.084034    15.055462         11.051941
# 719        36850.8276 -0.637107     0.084906    49.528365          9.084656
# 720        46434.9449 -0.112736     0.073113    36.091981          8.028381
# 721        79443.7256 -0.594714     0.058571    41.768286          4.912903
# 722        63830.3921 -0.166667     0.076389    37.140451          8.674866
# 723        44607.0902 -0.289974     0.092545    41.635244          9.549377
# 724        51191.5757 -0.604545     0.077273    40.810250          6.322083
# 725        22039.9980 -0.191787     0.077295    26.147343          9.485779
# 726        44151.2888 -0.554822     0.068528    53.496726          8.736877
# 727        26066.1715 -0.809649     0.074561    42.359254          7.855774
# 728        43014.9137 -0.379683     0.084433    38.500554          9.150330
# 729        35572.1550 -0.530000     0.093548    33.280645          7.086487
# 730        13932.3471 -0.636975     0.092437    37.616050         10.322449
# 731        79443.7256 -0.610526     0.124654    29.449889          5.946960
# 732        35596.0269  0.140533     0.050296    31.594379          8.824280
# 733        44607.0902 -0.422222     0.141414    22.196970         10.662659
# 734        56911.2873 -0.360039     0.100394    41.887441          8.859558
# 735        22039.9980 -0.319403     0.094980    31.798643          9.124573
# 736       115744.1632 -0.431337     0.097804    41.931677          8.430969
#
#       Compartment
# 0         Cytosol
# 1         Cytosol
# 2         Cytosol
# 3         Cytosol
# 4         Cytosol
# 5         Cytosol
# 6         Cytosol
# 7         Cytosol
# 8         Cytosol
# 9         Cytosol
# 10        Cytosol
# 11        Cytosol
# 12        Cytosol
# 13        Cytosol
# 14        Cytosol
# 15        Cytosol
# 16        Cytosol
# 17        Cytosol
# 18        Cytosol
# 19        Cytosol
# 20        Cytosol
# 21        Cytosol
# 22        Cytosol
# 23        Cytosol
# 24        Cytosol
# 25        Cytosol
# 26        Cytosol
# 27        Cytosol
# 28        Cytosol
# 29        Cytosol
# ..            ...
# 707  Mitochondria
# 708  Mitochondria
# 709  Mitochondria
# 710  Mitochondria
# 711  Mitochondria
# 712  Mitochondria
# 713  Mitochondria
# 714  Mitochondria
# 715  Mitochondria
# 716  Mitochondria
# 717  Mitochondria
# 718  Mitochondria
# 719  Mitochondria
# 720  Mitochondria
# 721  Mitochondria
# 722  Mitochondria
# 723  Mitochondria
# 724  Mitochondria
# 725  Mitochondria
# 726  Mitochondria
# 727  Mitochondria
# 728  Mitochondria
# 729  Mitochondria
# 730  Mitochondria
# 731  Mitochondria
# 732  Mitochondria
# 733  Mitochondria
# 734  Mitochondria
# 735  Mitochondria
# 736  Mitochondria
#
# [737 rows x 6 columns]

# %%
# 3. Understanding Data
print(data.describe())
# Out:
#        Molecular_Weight     Gravity  Aromaticity  Instability  \
# count        737.000000  737.000000   737.000000   737.000000
# 715        73778.7780 -0.406333     0.047128    39.134624          5.970642
# 716        43226.0110 -0.788410     0.088949    50.470108          9.819275
# 717        35079.1508  0.145946     0.054054    27.451652          8.617615
# 718        13625.2014 -0.323529     0.084034    15.055462         11.051941
# 719        36850.8276 -0.637107     0.084906    49.528365          9.084656
# 720        46434.9449 -0.112736     0.073113    36.091981          8.028381
# 721        79443.7256 -0.594714     0.058571    41.768286          4.912903
# 722        63830.3921 -0.166667     0.076389    37.140451          8.674866
# 723        44607.0902 -0.289974     0.092545    41.635244          9.549377
# 724        51191.5757 -0.604545     0.077273    40.810250          6.322083
# 725        22039.9980 -0.191787     0.077295    26.147343          9.485779
# 726        44151.2888 -0.554822     0.068528    53.496726          8.736877
# 727        26066.1715 -0.809649     0.074561    42.359254          7.855774
# 728        43014.9137 -0.379683     0.084433    38.500554          9.150330
# 729        35572.1550 -0.530000     0.093548    33.280645          7.086487
# 730        13932.3471 -0.636975     0.092437    37.616050         10.322449
# 731        79443.7256 -0.610526     0.124654    29.449889          5.946960
# 732        35596.0269  0.140533     0.050296    31.594379          8.824280
# 733        44607.0902 -0.422222     0.141414    22.196970         10.662659
# 734        56911.2873 -0.360039     0.100394    41.887441          8.859558
# 735        22039.9980 -0.319403     0.094980    31.798643          9.124573
# 736       115744.1632 -0.431337     0.097804    41.931677          8.430969
#
#       Compartment
# 0         Cytosol
# 1         Cytosol
# 2         Cytosol
# 3         Cytosol
# 4         Cytosol
# 5         Cytosol
# 6         Cytosol
# 7         Cytosol
# 8         Cytosol
# 9         Cytosol
# 10        Cytosol
# 11        Cytosol
# 12        Cytosol
# 13        Cytosol
# 14        Cytosol
# 15        Cytosol
# 16        Cytosol
# 17        Cytosol
# 18        Cytosol
# 19        Cytosol
# 20        Cytosol
# 21        Cytosol
# 22        Cytosol
# 23        Cytosol
# 24        Cytosol
# 25        Cytosol
# 26        Cytosol
# 27        Cytosol
# 28        Cytosol
# 29        Cytosol
# ..            ...
# 707  Mitochondria
# 708  Mitochondria
# 709  Mitochondria
# 710  Mitochondria
# 711  Mitochondria
# 712  Mitochondria
# 713  Mitochondria
# 714  Mitochondria
# 715  Mitochondria
# 716  Mitochondria
# 717  Mitochondria
# 718  Mitochondria
# 719  Mitochondria
# 720  Mitochondria
# 721  Mitochondria
# 722  Mitochondria
# 723  Mitochondria
# 724  Mitochondria
# 725  Mitochondria
# 726  Mitochondria
# 727  Mitochondria
# 728  Mitochondria
# 729  Mitochondria
# 730  Mitochondria
# 731  Mitochondria
# 732  Mitochondria
# 733  Mitochondria
# 734  Mitochondria
# 735  Mitochondria
# 736  Mitochondria
#
# [737 rows x 6 columns]>

# %%
# 4. Split Input and Output Features
TrainingSample,TestSample=train_test_split(data, test_size=0.3, random_state=2 ) #default is 25% starts at row number 2
print ("Training Set")
print(TrainingSample)
print("Testing Sample")
print(TestSample)
# Out:
# Training Set
#      Molecular_Weight   Gravity  Aromaticity  Instability  Isoelectic_Point  \
# 658        29789.1132 -0.423792     0.078067    31.026022         10.234070
# 263        52896.9171 -0.336831     0.079229    48.465760          5.536194
# 360        27869.6792  0.156274     0.079848    32.796198          6.788879
# 75         29062.5430 -0.385827     0.122047    41.612598          5.135559
# 466        92340.8609 -0.415810     0.226614    36.038300          5.591492
# 299       102726.0835 -0.422901     0.073064    48.007197          5.258850
# 534        26517.5842 -0.619397     0.094828    30.578922         10.321716
# 584        71127.8085 -0.316044     0.068536    51.832259          8.978333
# 493        20666.9270 -0.445304     0.154696    30.209392          6.888000
# 527        60234.0316 -0.184934     0.103578    49.519416          9.045593
# 168        77851.1107 -0.281129     0.118871    41.496018          5.511047
#
#        Compartment
# 658   Mitochondria
# 479  Extracellular
# 134        Cytosol
# 155        Cytosol
# 605   Mitochondria
# 139        Cytosol
# 565   Mitochondria
# 480  Extracellular
# 60         Cytosol
# 546   Mitochondria
# 656   Mitochondria
# 165        Cytosol
# 626   Mitochondria
# 467  Extracellular
# 558   Mitochondria
# 250        Cytosol
# 381  Extracellular
# 280        Cytosol
# 526   Mitochondria
# 273        Cytosol
# 131        Cytosol
# 58         Cytosol
# 436  Extracellular
# 638   Mitochondria
# 735   Mitochondria
# 160        Cytosol
# 334        Cytosol
# 38         Cytosol
# 318        Cytosol
# 249        Cytosol
# ..             ...
# 325        Cytosol
# 323        Cytosol
# 255        Cytosol
# 570   Mitochondria
# 545   Mitochondria
# 550   Mitochondria
# 359  Extracellular
# 51         Cytosol
# 102        Cytosol
# 195        Cytosol
# 679   Mitochondria
# 628   Mitochondria
# 124        Cytosol
# 404  Extracellular
# 287        Cytosol
# 47         Cytosol
# 587   Mitochondria
# 607   Mitochondria
# 433  Extracellular
# 674   Mitochondria
# 263        Cytosol
# 360  Extracellular
# 75         Cytosol
# 466  Extracellular
# 299        Cytosol
# 534   Mitochondria
# 584   Mitochondria
# 493  Extracellular
# 527   Mitochondria
# 168        Cytosol
#
# [515 rows x 6 columns]
# Testing Sample
#      Molecular_Weight   Gravity  Aromaticity  Instability  Isoelectic_Point  \
# 20         34582.6007 -0.087459     0.099010    42.583531          7.625671
# 176        37027.1267 -0.339130     0.102484    36.507174          6.669617
# 518        48618.9604 -0.196070     0.048035    35.562664          6.229675
# 372        41423.4151 -0.234946     0.077957    47.767742          5.196350
# 213        80762.6070 -0.324648     0.126761    37.216972          5.484192
# 637        66747.6137 -0.460348     0.113043    37.042817          8.905945
# 382        19689.0508  0.348387     0.053763    36.440860          7.601501
# 659        30048.7357 -0.732558     0.104651    44.776744         10.131653
# 338        22732.6332 -0.422388     0.069652    46.958209          7.866028
# 715        73778.7780 -0.406333     0.047128    39.134624          5.970642
# 30         32417.4537 -0.265411     0.102740    38.674315          7.211121
# 458        37049.4822 -0.418349     0.103976    35.760245          5.823547
# 369        52285.5941 -0.475546     0.102620    37.852838          6.858337
# 520        44367.9105 -0.446329     0.106329    30.268608          9.104187
# 275        75029.6974 -0.496988     0.088855    41.554985          5.993835
# 613        42719.9441 -0.797253     0.090659    39.150577          9.739075
# 15         21898.8698 -0.076119     0.084577    47.526368          6.146667
# 613   Mitochondria
# 15         Cytosol
# 463  Extracellular
# 399  Extracellular
# 455  Extracellular
# 409  Extracellular
# 583   Mitochondria
# 346  Extracellular
# 284        Cytosol
# 74         Cytosol
# 448  Extracellular
# 643   Mitochondria
# 700   Mitochondria
# 22         Cytosol
# 62         Cytosol
# ..             ...
# 130        Cytosol
# 563   Mitochondria
# 120        Cytosol
# 7          Cytosol
# 701   Mitochondria
# 304        Cytosol
# 496  Extracellular
# 549   Mitochondria
# 12         Cytosol
# 171        Cytosol
# 601   Mitochondria
# 248        Cytosol
# 495  Extracellular
# 377  Extracellular
# 589   Mitochondria
# 289        Cytosol
# 101        Cytosol
# 123        Cytosol
# 212        Cytosol
# 180        Cytosol
# 161        Cytosol
# 347  Extracellular
# 152        Cytosol
# 117        Cytosol
# 705   Mitochondria
# 432  Extracellular
# 344  Extracellular
# 492  Extracellular
# 471  Extracellular
# 388  Extracellular
#
# [222 rows x 6 columns]

# %%
# 5. Splitting Input and Output Variables
# Slice the input variables Data
Training_InputVariables=TrainingSample.values[:,0:5]

# Slice the Output Variable Data
Training_OutputVariable=TrainingSample.values[:,5]
print("Input Variables of Training Data")
print (Training_InputVariables)
print("Output Variables of Training Data")
print (Training_OutputVariable)
# Out:
# Input Variables of Training Data
# [[29789.1132 -0.42379182200000004 0.078066914 31.0260223 10.23406982]
#  [93088.1911 -0.414099526 0.08056872 40.082109 8.028869628999999]
#  [22762.9771 0.07358490599999999 0.099056604 6.573113208 8.47857666]
#  ...
#  [20666.927 -0.445303867 0.154696133 30.20939227 6.888000487999999]
#  [60234.0316 -0.184934087 0.103578154 49.5194162 9.045593262]
#  [77851.1107 -0.281129272 0.11887072800000001 41.49601783
#   5.511047362999999]]
# Output Variables of Training Data
# ['Mitochondria' 'Extracellular' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Mitochondria' 'Extracellular' 'Cytosol' 'Mitochondria'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Extracellular' 'Mitochondria'
#  'Cytosol' 'Extracellular' 'Cytosol' 'Mitochondria' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Extracellular' 'Mitochondria' 'Mitochondria' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Extracellular'
#  'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol'
#  'Extracellular' 'Extracellular' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Extracellular' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Extracellular' 'Cytosol' 'Cytosol' 'Mitochondria' 'Extracellular'
#  'Mitochondria' 'Mitochondria' 'Cytosol' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Cytosol' 'Cytosol' 'Extracellular'
#  'Mitochondria' 'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Extracellular' 'Mitochondria' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol'
#  'Mitochondria' 'Extracellular' 'Mitochondria' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Mitochondria' 'Extracellular' 'Mitochondria' 'Extracellular'
#  'Mitochondria' 'Extracellular' 'Extracellular' 'Mitochondria' 'Cytosol'
#  'Extracellular' 'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Mitochondria' 'Extracellular'
#  'Mitochondria' 'Mitochondria' 'Cytosol' 'Cytosol' 'Extracellular'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Mitochondria'
#  'Cytosol' 'Mitochondria' 'Extracellular' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Extracellular' 'Mitochondria' 'Mitochondria'
#  'Mitochondria' 'Mitochondria' 'Cytosol' 'Cytosol' 'Extracellular'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Cytosol' 'Cytosol' 'Extracellular'
#  'Mitochondria' 'Mitochondria' 'Mitochondria' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Mitochondria' 'Cytosol' 'Extracellular' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Mitochondria' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Extracellular' 'Mitochondria' 'Cytosol' 'Extracellular'
#  'Cytosol' 'Cytosol' 'Extracellular' 'Extracellular' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Mitochondria' 'Extracellular' 'Extracellular' 'Mitochondria'
#  'Extracellular' 'Mitochondria' 'Mitochondria' 'Cytosol' 'Extracellular'
#  'Mitochondria' 'Mitochondria' 'Extracellular' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Extracellular' 'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Cytosol' 'Extracellular' 'Mitochondria'
#  'Mitochondria' 'Mitochondria' 'Extracellular' 'Extracellular' 'Cytosol'
#  'Extracellular' 'Mitochondria' 'Extracellular' 'Cytosol' 'Extracellular'
#  'Cytosol' 'Extracellular' 'Mitochondria' 'Mitochondria' 'Mitochondria'
#  'Cytosol' 'Mitochondria' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Extracellular' 'Cytosol' 'Cytosol' 'Mitochondria' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Extracellular'
#  'Mitochondria' 'Extracellular' 'Mitochondria' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Extracellular' 'Extracellular'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Mitochondria' 'Mitochondria' 'Cytosol'
#  'Cytosol' 'Extracellular' 'Mitochondria' 'Extracellular' 'Cytosol'
#  'Mitochondria' 'Extracellular' 'Cytosol' 'Mitochondria' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol' 'Extracellular' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Extracellular' 'Mitochondria' 'Mitochondria' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Extracellular'
#  'Cytosol' 'Mitochondria' 'Mitochondria' 'Cytosol' 'Extracellular'
#  'Mitochondria' 'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Cytosol' 'Mitochondria' 'Extracellular'
#  'Mitochondria' 'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol'
#  'Extracellular' 'Extracellular' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Mitochondria' 'Extracellular'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Extracellular' 'Cytosol'
#  'Cytosol' 'Mitochondria' 'Extracellular' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Mitochondria' 'Mitochondria' 'Mitochondria' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol' 'Extracellular' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Extracellular' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Extracellular' 'Mitochondria' 'Mitochondria' 'Cytosol'
#  'Cytosol' 'Mitochondria' 'Extracellular' 'Mitochondria' 'Mitochondria'
#  'Cytosol' 'Extracellular' 'Mitochondria' 'Extracellular' 'Mitochondria'
#  'Extracellular' 'Mitochondria' 'Extracellular' 'Cytosol' 'Extracellular'
#  'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Mitochondria' 'Mitochondria'
#  'Cytosol' 'Mitochondria' 'Cytosol' 'Extracellular' 'Mitochondria'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Cytosol' 'Extracellular'
#  'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol' 'Extracellular'
#  'Extracellular' 'Cytosol' 'Mitochondria' 'Mitochondria' 'Extracellular'
#  'Cytosol' 'Mitochondria' 'Mitochondria' 'Mitochondria' 'Extracellular'
#  'Cytosol' 'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Extracellular' 'Mitochondria' 'Mitochondria' 'Cytosol' 'Cytosol'
#  'Extracellular' 'Extracellular' 'Extracellular' 'Mitochondria'
#  'Mitochondria' 'Extracellular' 'Extracellular' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Extracellular' 'Mitochondria'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Extracellular' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Extracellular' 'Extracellular' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Mitochondria' 'Mitochondria' 'Mitochondria'
#  'Extracellular' 'Cytosol' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Mitochondria' 'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Extracellular' 'Mitochondria' 'Cytosol'
#  'Extracellular' 'Cytosol' 'Extracellular' 'Cytosol' 'Mitochondria'
#  'Mitochondria' 'Extracellular' 'Mitochondria' 'Cytosol']

# %%
# 6. Splitting Test Input and Output Variables
# Slice the input variables Data
Test_InputVariables=TestSample.values[:,0:5]

# Slice the Output Variable Data
Test_OutputVariable=TestSample.values[:,5]
print("Input Variables of Test Data")
print (Test_InputVariables)
print("Output Variables of Test Data")
print (Test_OutputVariable)
# Out:
# Input Variables of Test Data
# [[34582.6007 -0.08745874599999999 0.099009901 42.58353135
#   7.625671387000001]
#  [37027.1267 -0.339130435 0.102484472 36.50717391 6.669616699]
#  [48618.9604 -0.19606986899999998 0.048034934 35.56266376 6.229675293]
#  ...
#  [240715.7448 -0.37157799 0.07276034599999999 33.61810368 4.79864502]
#  [25107.0179 -0.15401785699999998 0.0625 94.121875 5.257385254]
#  [28685.1228 0.039483395 0.081180812 24.80073801 5.737243652]]
# Output Variables of Test Data
# ['Cytosol' 'Cytosol' 'Mitochondria' 'Extracellular' 'Cytosol'
#  'Mitochondria' 'Extracellular' 'Mitochondria' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Extracellular' 'Extracellular' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Extracellular' 'Extracellular' 'Extracellular'
#  'Extracellular' 'Mitochondria' 'Extracellular' 'Cytosol' 'Cytosol'
#  'Extracellular' 'Mitochondria' 'Mitochondria' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Extracellular' 'Mitochondria' 'Mitochondria' 'Mitochondria' 'Cytosol'
#  'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol' 'Extracellular'
#  'Extracellular' 'Mitochondria' 'Mitochondria' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Mitochondria' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol' 'Mitochondria'
#  'Mitochondria' 'Extracellular' 'Cytosol' 'Extracellular' 'Extracellular'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular'
#  'Mitochondria' 'Mitochondria' 'Cytosol' 'Mitochondria' 'Extracellular'
#  'Extracellular' 'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol'
#  'Extracellular' 'Mitochondria' 'Cytosol' 'Mitochondria' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Mitochondria' 'Extracellular' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Extracellular' 'Extracellular' 'Cytosol' 'Cytosol'
#  'Extracellular' 'Extracellular' 'Cytosol' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Extracellular' 'Mitochondria' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Extracellular' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Extracellular' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Extracellular' 'Mitochondria' 'Mitochondria'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol'
#  'Extracellular' 'Mitochondria' 'Cytosol' 'Mitochondria' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol' 'Extracellular'
#  'Extracellular' 'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Mitochondria' 'Extracellular' 'Extracellular'
#  'Extracellular' 'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Extracellular' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Extracellular' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol'
#  'Extracellular' 'Mitochondria' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Extracellular' 'Extracellular' 'Mitochondria' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular'
#  'Cytosol' 'Cytosol' 'Mitochondria' 'Extracellular' 'Extracellular'
#  'Extracellular' 'Extracellular' 'Extracellular']

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
Training_InputVariables = sc.fit_transform(Training_InputVariables)
Test_InputVariables= sc.transform(Test_InputVariables)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# 6. Fitting Random Forest Classifier
# Loading Libraries
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
# Set random seed
#np.random.seed(0)
# Build a tree model of three layers

classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)

# %%
#7. Training The model
classifier.fit(Training_InputVariables, Training_OutputVariable)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=4, n_jobs=None,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
# 8. Predicting the Test set results

Testdata_pred = classifier.predict(Test_InputVariables)
print(Testdata_pred)
# Out:
# ['Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Cytosol' 'Extracellular'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol' 'Mitochondria'
#  'Extracellular' 'Mitochondria' 'Extracellular' 'Extracellular' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Mitochondria' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol' 'Mitochondria'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Extracellular' 'Mitochondria' 'Mitochondria' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol' 'Mitochondria'
#  'Mitochondria' 'Extracellular' 'Mitochondria' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Mitochondria'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Extracellular' 'Extracellular'
#  'Extracellular' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Mitochondria' 'Mitochondria' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Extracellular' 'Mitochondria' 'Cytosol' 'Mitochondria'
#  'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Extracellular' 'Cytosol' 'Cytosol' 'Extracellular'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Mitochondria' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Mitochondria' 'Mitochondria'
#  'Extracellular' 'Mitochondria' 'Extracellular' 'Mitochondria' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Mitochondria' 'Cytosol' 'Extracellular' 'Extracellular'
#  'Cytosol' 'Extracellular' 'Mitochondria' 'Mitochondria' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Extracellular' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Extracellular' 'Mitochondria' 'Extracellular' 'Cytosol'
#  'Extracellular' 'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Mitochondria' 'Mitochondria'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Extracellular' 'Extracellular' 'Cytosol' 'Mitochondria' 'Extracellular'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Mitochondria'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol' 'Cytosol'
#  'Mitochondria' 'Cytosol' 'Cytosol' 'Mitochondria' 'Cytosol'
#  'Mitochondria' 'Mitochondria' 'Mitochondria' 'Mitochondria' 'Cytosol'
#  'Cytosol' 'Cytosol' 'Cytosol' 'Mitochondria' 'Extracellular'
#  'Mitochondria' 'Cytosol' 'Mitochondria' 'Extracellular' 'Extracellular'
#  'Cytosol' 'Cytosol' 'Extracellular']

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Test_OutputVariable, Testdata_pred)
cm
# Out:
# array([[77, 12, 13],
#        [29, 17,  5],
#        [21,  6, 42]], dtype=int64)
